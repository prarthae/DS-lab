# %%
from sklearn import datasets
from sklearn import tree #import tree module from
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
iris=datasets.load_iris()

# %%
features=iris.feature_names

# %%
target=iris.target_names

# %%
X,y=iris.data,iris.target

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.7)

# %%
classifier=tree.DecisionTreeClassifier(random_state=0)

# %%
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred=classifier.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9333333333333333

# %%
result=classifier.predict([[3.4,5.4,4.2,2.1]])
result
print(datasets.load_iris().target_names[result])
# Out:
# ['virginica']

# %%
result=classifier.predict([[4,5,5,3]])
result
print(datasets.load_iris().target_names[result])
# Out:
# ['virginica']

# %%
result=classifier.predict([[1.6,2.5,1.7,3]])
result
print(datasets.load_iris().target_names[result])
# Out:
# ['virginica']

# %%
tree.plot_tree(classifier)
# Out:
# [Text(0.3333333333333333, 0.9166666666666666, 'x[3] <= 0.7\ngini = 0.66\nsamples = 45\nvalue = [14.0, 13.0, 18.0]'),
#  Text(0.16666666666666666, 0.75, 'gini = 0.0\nsamples = 14\nvalue = [14, 0, 0]'),
#  Text(0.5, 0.75, 'x[3] <= 1.75\ngini = 0.487\nsamples = 31\nvalue = [0, 13, 18]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'x[0] <= 5.15\ngini = 0.231\nsamples = 15\nvalue = [0, 13, 2]'),
#  Text(0.16666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5, 0.4166666666666667, 'x[2] <= 5.05\ngini = 0.133\nsamples = 14\nvalue = [0, 13, 1]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0]'),
#  Text(0.6666666666666666, 0.25, 'x[3] <= 1.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
# ...
