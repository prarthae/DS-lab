# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 2 Question
x=[12,14,16,18,20,22,24]
y=[100,200,250,400,300,450,500]

plt.title("Temperature v/s Sales")
plt.xlabel("Temperature")
plt.ylabel("Sale")
plt.plot(x,y,marker="*")
plt.show()

# %%
# 1 Question
x=[1,2,6,18]
y=[3,10,12,20]

plt.title("x-y ")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.plot(x,y,'--',color='red',markerfacecolor='green',marker='o')
plt.show()

# %%
# 3 Question
import matplotlib.pyplot as plt
import numpy as np

# File path to the text file
file_path = 'cordinates.txt'

# Read data from the file
x_values = []
y_values = []

with open(file_path, 'r') as file:
    lines = file.readlines()
    for line in lines[0:]:  # Skip the header line
        x, y = map(float, line.split())
        x_values.append(x)
        y_values.append(y)

# Convert lists to numpy arrays
x_values = np.array(x_values)
y_values = np.array(y_values)

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, marker='o', linestyle='-', color='b')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Plot from File Data')
plt.grid(True)
plt.show()
